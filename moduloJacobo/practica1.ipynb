# %% [markdown]
# ## PRACTICA1

# %% [markdown]
# ## Importar paqueterias y cargar la base de datos

# %%
import pandas as pd 
import numpy as np
path = '/home/vagrant/fuerocomunmunicipios.csv'

# %%
df = pd.read_csv(path, encoding='utf-8',quotechar=None, quoting=3,low_memory=False)
df.head()
# Out:
#    state_code  mun_code  year  month                    crime  \
# 0           1         1  2011      1  "DELITOS PATRIMONIALES"
# 1           1         1  2011      2  "DELITOS PATRIMONIALES"
# 2           1         1  2011      3  "DELITOS PATRIMONIALES"
# 3           1         1  2011      4  "DELITOS PATRIMONIALES"
# 4           1         1  2011      5  "DELITOS PATRIMONIALES"
#
#                   category                  type               subtype  count  \
# 0  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   44.0
# 1  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   43.0
# 2  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   34.0
# 3  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   21.0
# 4  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   35.0
#
#    population
# 0    811483.0
# 1    812551.0
# 2    813619.0
# 3    814686.0
# 4    815754.0

# %%
df.shape
# Out:
# (184917, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184917 entries, 0 to 184916
# Data columns (total 10 columns):
# state_code    184917 non-null int64
# mun_code      184917 non-null int64
# year          184917 non-null int64
# month         184917 non-null int64
# crime         184917 non-null object
# category      184917 non-null object
# type          184916 non-null object
# subtype       184916 non-null object
# count         146058 non-null float64
# population    184916 non-null float64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 14.1+ MB

# %%
lista=df.columns.values.tolist()

# %%
df[['year','crime']+['count']]
# Out:
#         year                    crime  count
# 0       2011  "DELITOS PATRIMONIALES"   44.0
# 1       2011  "DELITOS PATRIMONIALES"   43.0
# 2       2011  "DELITOS PATRIMONIALES"   34.0
# 3       2011  "DELITOS PATRIMONIALES"   21.0
# 4       2011  "DELITOS PATRIMONIALES"   35.0
# ...      ...                      ...    ...
# 184912  2013  "DELITOS PATRIMONIALES"    0.0
# 184913  2013  "DELITOS PATRIMONIALES"    0.0
# 184914  2013  "DELITOS PATRIMONIALES"    0.0
# 184915  2013  "DELITOS PATRIMONIALES"    0.0
# 184916  2014  "DELITOS PATRIMONIALES"    NaN
#
# [184917 rows x 3 columns]

# %%
df.shape[0]
# Out:
# 184917

# %%
df.shape[1]
# Out:
# 10

# %%
df.columns.values.tolist()
# Out:
# ['state_code',
#  'mun_code',
#  'year',
#  'month',
#  'crime',
#  'category',
#  'type',
#  'subtype',
#  'count',
#  'population']

# %%
df.dtypes
# Out:
# state_code      int64
# mun_code        int64
# year            int64
# month           int64
# crime          object
# category       object
# type           object
# subtype        object
# count         float64
# population    float64
# dtype: object

# %%
df.isnull().any().any()
# Out:
# True

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# ['type', 'subtype', 'count', 'population']

# %%
len(pd.isnull(df).any(1).to_numpy().nonzero()[0].tolist())
# Out:
# 38859

# %%
pd.isnull(df).any(1).to_numpy().nonzero()[0].tolist()[0:5]
# Out:
# [941, 946, 2661, 2741, 2781]

# %%
df.describe()
# Out:
#           state_code       mun_code           year          month  \
# count  184917.000000  184917.000000  184917.000000  184917.000000
# mean        3.858499      13.006684    2012.199971       6.100050
# std         1.515039      10.948002       0.979780       3.505724
# min         1.000000       1.000000    2011.000000       1.000000
# 25%         3.000000       4.000000    2011.000000       3.000000
# 50%         5.000000       9.000000    2012.000000       6.000000
# 75%         5.000000      21.000000    2013.000000       9.000000
# max         6.000000      38.000000    2014.000000      12.000000
#
#                count    population
# count  146058.000000  1.849160e+05
# mean        4.653261  1.286213e+05
# std        33.097144  2.672680e+05
# min         0.000000  1.092000e+03
# 25%         0.000000  1.132800e+04
# 50%         0.000000  4.046500e+04
# 75%         0.000000  9.876400e+04
# max      1078.000000  1.692086e+06

# %%
df.loc[[0]]
# Out:
#    state_code  mun_code  year  month                    crime  \
# 0           1         1  2011      1  "DELITOS PATRIMONIALES"
#
#                   category                  type               subtype  count  \
# 0  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   44.0
#
#    population
# 0    811483.0

# %%
df.loc[30:33]
# Out:
#     state_code  mun_code  year  month                    crime  \
# 30           1         1  2013      7  "DELITOS PATRIMONIALES"
# 31           1         1  2013      8  "DELITOS PATRIMONIALES"
# 32           1         1  2013      9  "DELITOS PATRIMONIALES"
# 33           1         1  2013     10  "DELITOS PATRIMONIALES"
#
#                    category                  type               subtype  \
# 30  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"
# 31  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"
# 32  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"
# 33  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"
#
#     count  population
# 30   47.0    842391.0
# 31   48.0    843374.0
# 32   39.0    844358.0
# 33   42.0    845341.0

# %%
df.drop([0,2], axis=0).head()
# Out:
#    state_code  mun_code  year  month                    crime  \
# 1           1         1  2011      2  "DELITOS PATRIMONIALES"
# 3           1         1  2011      4  "DELITOS PATRIMONIALES"
# 4           1         1  2011      5  "DELITOS PATRIMONIALES"
# 5           1         1  2011      6  "DELITOS PATRIMONIALES"
# 6           1         1  2011      7  "DELITOS PATRIMONIALES"
#
#                   category                  type               subtype  count  \
# 1  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   43.0
# 3  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   21.0
# 4  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   35.0
# 5  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   43.0
# 6  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   42.0
#
#    population
# 1    812551.0
# 3    814686.0
# 4    815754.0
# 5    816822.0
# 6    817861.0

# %%
df.drop(df.index[1:5], axis=0).head(10)
# Out:
#     state_code  mun_code  year  month                    crime  \
# 0            1         1  2011      1  "DELITOS PATRIMONIALES"
# 5            1         1  2011      6  "DELITOS PATRIMONIALES"
# 6            1         1  2011      7  "DELITOS PATRIMONIALES"
# 7            1         1  2011      8  "DELITOS PATRIMONIALES"
# 8            1         1  2011      9  "DELITOS PATRIMONIALES"
# 9            1         1  2011     10  "DELITOS PATRIMONIALES"
# 10           1         1  2011     11  "DELITOS PATRIMONIALES"
# 11           1         1  2011     12  "DELITOS PATRIMONIALES"
# 12           1         1  2012      1  "DELITOS PATRIMONIALES"
# 13           1         1  2012      2  "DELITOS PATRIMONIALES"
#
#                    category                  type               subtype  \
# 0   "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"
# 5   "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"
# 6   "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"
# 7   "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"
# 8   "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"
# 9   "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"
# 10  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"
# 11  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"
# 12  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"
# 13  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"
#
#     count  population
# 0    44.0    811483.0
# 5    43.0    816822.0
# 6    42.0    817861.0
# 7    37.0    818900.0
# 8    36.0    819939.0
# 9    37.0    820978.0
# 10   31.0    822017.0
# 11   27.0    823056.0
# 12   50.0    824094.0
# 13   52.0    825133.0

# %%
df[100:].head()
# Out:
#      state_code  mun_code  year  month                    crime  \
# 100           1         1  2012      9  "DELITOS PATRIMONIALES"
# 101           1         1  2012     10  "DELITOS PATRIMONIALES"
# 102           1         1  2012     11  "DELITOS PATRIMONIALES"
# 103           1         1  2012     12  "DELITOS PATRIMONIALES"
# 104           1         1  2013      1  "DELITOS PATRIMONIALES"
#
#                     category     type          subtype  count  population
# 100  "DELITOS PATRIMONIALES"  DESPOJO  "CON VIOLENCIA"    0.0    832319.0
# 101  "DELITOS PATRIMONIALES"  DESPOJO  "CON VIOLENCIA"    0.0    833329.0
# 102  "DELITOS PATRIMONIALES"  DESPOJO  "CON VIOLENCIA"    0.0    834339.0
# 103  "DELITOS PATRIMONIALES"  DESPOJO  "CON VIOLENCIA"    0.0    835348.0
# 104  "DELITOS PATRIMONIALES"  DESPOJO  "CON VIOLENCIA"    0.0    836358.0

# %%
df.crime.values
# Out:
# array(['"DELITOS PATRIMONIALES"', '"DELITOS PATRIMONIALES"',
#        '"DELITOS PATRIMONIALES"', ..., '"DELITOS PATRIMONIALES"',
#        '"DELITOS PATRIMONIALES"', '"DELITOS PATRIMONIALES"'], dtype=object)

# %%
df.crime.unique()
# Out:
# array(['"DELITOS PATRIMONIALES"', '"DELITOS SEXUALES"', 'HOMICIDIOS',
#        'LESIONES', '"OTROS DELITOS"',
#        '"PRIV. DE LA LIBERTAD (SECUESTRO)"', 'ROBOS'], dtype=object)

# %%
df.crime.value_counts()
# Out:
# ROBOS                                 103600
# LESIONES                               22400
# HOMICIDIOS                             22400
# "DELITOS PATRIMONIALES"                19717
# "OTROS DELITOS"                        11200
# "PRIV. DE LA LIBERTAD (SECUESTRO)"      2800
# "DELITOS SEXUALES"                      2800
# Name: crime, dtype: int64

# %%
df.agg(['count', 'size', 'nunique'])
# Out:
#          state_code  mun_code    year   month   crime  category    type  \
# count        184917    184917  184917  184917  184917    184917  184916
# size         184917    184917  184917  184917  184917    184917  184917
# nunique           6        38       4      12       7        11      18
#
#          subtype   count  population
# count     184916  146058      184916
# size      184917  184917      184917
# nunique       29     536        2784

# %%
df.groupby('state_code').agg(['count', 'size', 'nunique']).stack()
# Out:
#                     mun_code    year   month   crime  category    type  \
# state_code
# 1          count       29040   29040   29040   29040     29040   29040
#            size        29040   29040   29040   29040     29040   29040
#            nunique        11       4      12       7        10      18
# 2          count       13200   13200   13200   13200     13200   13200
#            size        13200   13200   13200   13200     13200   13200
#            nunique         5       4      12       7        10      18
# 3          count       13200   13200   13200   13200     13200   13200
#            size        13200   13200   13200   13200     13200   13200
#            nunique         5       4      12       7        10      18
# 4          count       29040   29040   29040   29040     29040   29040
#            size        29040   29040   29040   29040     29040   29040
#            nunique        11       4      12       7        10      18
# 5          count      100320  100320  100320  100320    100320  100320
#            size       100320  100320  100320  100320    100320  100320
#            nunique        38       4      12       7        10      18
# 6          count         117     117     117     117       117     116
#            size          117     117     117     117       117     117
#            nunique         1       4      12       1         2       3
#
#                     subtype   count  population
# state_code
# 1          count      29040   28904       29040
#            size       29040   29040       29040
#            nunique       29     219         440
# 2          count      13200    5392       13200
#            size       13200   13200       13200
#            nunique       29     521         200
# 3          count      13200   10200       13200
#            size       13200   13200       13200
#            nunique       29     215         200
# 4          count      29040   28973       29040
#            size       29040   29040       29040
#            nunique       29      37         439
# 5          count     100320   72473      100320
#            size      100320  100320      100320
#            nunique       29     216        1482
# 6          count        116     116         116
#            size         117     117         117
#            nunique        3       4          40

# %%
df.groupby('state_code').agg(['count', 'size', 'nunique'])
# Out:
#            mun_code                    year                   month          \
#               count    size nunique   count    size nunique   count    size
# state_code
# 1             29040   29040      11   29040   29040       4   29040   29040
# 2             13200   13200       5   13200   13200       4   13200   13200
# 3             13200   13200       5   13200   13200       4   13200   13200
# 4             29040   29040      11   29040   29040       4   29040   29040
# 5            100320  100320      38  100320  100320       4  100320  100320
# 6               117     117       1     117     117       4     117     117
#
#                      crime  ...    type subtype                  count  \
#            nunique   count  ... nunique   count    size nunique  count
# state_code                  ...
# 1               12   29040  ...      18   29040   29040      29  28904
# 2               12   13200  ...      18   13200   13200      29   5392
# 3               12   13200  ...      18   13200   13200      29  10200
# 4               12   29040  ...      18   29040   29040      29  28973
# 5               12  100320  ...      18  100320  100320      29  72473
# 6               12     117  ...       3     116     117       3    116
#
#                            population
#               size nunique      count    size nunique
# state_code
# 1            29040     219      29040   29040     440
# 2            13200     521      13200   13200     200
# 3            13200     215      13200   13200     200
# 4            29040      37      29040   29040     439
# 5           100320     216     100320  100320    1482
# 6              117       4        116     117      40
#
# [6 rows x 27 columns]

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#        state_code  mun_code  year  month                    crime  \
# 64400           4         4  2011      1          "OTROS DELITOS"
# 74208           4         8  2011      9       "DELITOS SEXUALES"
# 54085           3         9  2011      6                    ROBOS
# 116             1         1  2014      1  "DELITOS PATRIMONIALES"
# 15158           1         6  2014      3                    ROBOS
#
#                              category               type             subtype  \
# 64400                 "OTROS DELITOS"  "OTROS SEXUALES "    "OTROS SEXUALES"
# 74208  "DELITOS SEXUALES (VIOLACION)"          VIOLACION           VIOLACION
# 54085                    "ROBO COMUN"    "CON VIOLENCIA"  "A TRANSPORTISTAS"
# 116           "DELITOS PATRIMONIALES"            DESPOJO     "CON VIOLENCIA"
# 15158            "ROBO EN CARRETERAS"    "CON VIOLENCIA"         "SIN DATOS"
#
#        count  population
# 64400    0.0     85337.0
# 74208    NaN     10099.0
# 54085    0.0     17998.0
# 116      0.0    848291.0
# 15158    0.0     43968.0

# %%
df_sample.shape
# Out:
# (9246, 10)

# %%
df_sample.groupby('state_code').agg(['count', 'size', 'nunique']).stack()
# Out:
#                     mun_code  year  month  crime  category  type  subtype  \
# state_code
# 1          count        1452  1452   1452   1452      1452  1452     1452
#            size         1452  1452   1452   1452      1452  1452     1452
#            nunique        11     4     12      7        10    18       29
# 2          count         716   716    716    716       716   716      716
#            size          716   716    716    716       716   716      716
#            nunique         5     4     12      7        10    18       29
# 3          count         643   643    643    643       643   643      643
#            size          643   643    643    643       643   643      643
#            nunique         5     4     12      7        10    18       29
# 4          count        1432  1432   1432   1432      1432  1432     1432
#            size         1432  1432   1432   1432      1432  1432     1432
#            nunique        11     4     12      7        10    18       29
# 5          count        4996  4996   4996   4996      4996  4996     4996
#            size         4996  4996   4996   4996      4996  4996     4996
#            nunique        38     4     12      7        10    18       29
# 6          count           7     7      7      7         7     7        7
#            size            7     7      7      7         7     7        7
#            nunique         1     2      6      1         1     3        3
#
#                     count  population
# state_code
# 1          count     1442        1452
#            size      1452        1452
#            nunique     41         421
# 2          count      274         716
#            size       716         716
#            nunique     95         195
# 3          count      510         643
#            size       643         643
#            nunique     44         196
# 4          count     1429        1432
#            size      1432        1432
#            nunique     15         422
# 5          count     3630        4996
#            size      4996        4996
#            nunique     82        1434
# 6          count        7           7
#            size         7           7
#            nunique      3           7

# %% [markdown]
# # DATA TRANSFORM

# %%
df_dropped = df.dropna(subset=['count'])
df_dropped.head()
# Out:
#    state_code  mun_code  year  month                    crime  \
# 0           1         1  2011      1  "DELITOS PATRIMONIALES"
# 1           1         1  2011      2  "DELITOS PATRIMONIALES"
# 2           1         1  2011      3  "DELITOS PATRIMONIALES"
# 3           1         1  2011      4  "DELITOS PATRIMONIALES"
# 4           1         1  2011      5  "DELITOS PATRIMONIALES"
#
#                   category                  type               subtype  count  \
# 0  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   44.0
# 1  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   43.0
# 2  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   34.0
# 3  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   21.0
# 4  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   35.0
#
#    population
# 0    811483.0
# 1    812551.0
# 2    813619.0
# 3    814686.0
# 4    815754.0

# %%
df_dropped.shape
# Out:
# (146058, 10)

# %%
df_copy = df.copy()
df_copy.head()
# Out:
#    state_code  mun_code  year  month                    crime  \
# 0           1         1  2011      1  "DELITOS PATRIMONIALES"
# 1           1         1  2011      2  "DELITOS PATRIMONIALES"
# 2           1         1  2011      3  "DELITOS PATRIMONIALES"
# 3           1         1  2011      4  "DELITOS PATRIMONIALES"
# 4           1         1  2011      5  "DELITOS PATRIMONIALES"
#
#                   category                  type               subtype  count  \
# 0  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   44.0
# 1  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   43.0
# 2  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   34.0
# 3  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   21.0
# 4  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   35.0
#
#    population
# 0    811483.0
# 1    812551.0
# 2    813619.0
# 3    814686.0
# 4    815754.0

# %%
df_dropped['count'].dtype
# Out:
# dtype('float64')

# %%
df_dropped['count'].mean()
# Out:
# 4.653261033288146

# %%
df_copy['count'].fillna(value=np.round(df['count'].mean(),decimals=0), inplace=True)

# %%
df_copy.agg(['count', 'size', 'nunique'])
# Out:
#          state_code  mun_code    year   month   crime  category    type  \
# count        184917    184917  184917  184917  184917    184917  184916
# size         184917    184917  184917  184917  184917    184917  184917
# nunique           6        38       4      12       7        11      18
#
#          subtype   count  population
# count     184916  184917      184916
# size      184917  184917      184917
# nunique       29     536        2784

# %%
df_sample = df_copy.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#        state_code  mun_code  year  month                    crime  \
# 64400           4         4  2011      1          "OTROS DELITOS"
# 74208           4         8  2011      9       "DELITOS SEXUALES"
# 54085           3         9  2011      6                    ROBOS
# 116             1         1  2014      1  "DELITOS PATRIMONIALES"
# 15158           1         6  2014      3                    ROBOS
#
#                              category               type             subtype  \
# 64400                 "OTROS DELITOS"  "OTROS SEXUALES "    "OTROS SEXUALES"
# 74208  "DELITOS SEXUALES (VIOLACION)"          VIOLACION           VIOLACION
# 54085                    "ROBO COMUN"    "CON VIOLENCIA"  "A TRANSPORTISTAS"
# 116           "DELITOS PATRIMONIALES"            DESPOJO     "CON VIOLENCIA"
# 15158            "ROBO EN CARRETERAS"    "CON VIOLENCIA"         "SIN DATOS"
#
#        count  population
# 64400    0.0     85337.0
# 74208    5.0     10099.0
# 54085    0.0     17998.0
# 116      0.0    848291.0
# 15158    0.0     43968.0

# %% [markdown]
# ## HANDLING CATEGORICAL DATA

# %%
list(df.crime.unique())
# Out:
# ['"DELITOS PATRIMONIALES"',
#  '"DELITOS SEXUALES"',
#  'HOMICIDIOS',
#  'LESIONES',
#  '"OTROS DELITOS"',
#  '"PRIV. DE LA LIBERTAD (SECUESTRO)"',
#  'ROBOS']

# %%
keys = list(df.crime.unique())
vals = range(1,8)
crime_map = dict(zip(keys, vals))
crime_map
# Out:
# {'"DELITOS PATRIMONIALES"': 1,
#  '"DELITOS SEXUALES"': 2,
#  'HOMICIDIOS': 3,
#  'LESIONES': 4,
#  '"OTROS DELITOS"': 5,
#  '"PRIV. DE LA LIBERTAD (SECUESTRO)"': 6,
#  'ROBOS': 7}

# %%
df_copy['crime_cat'] = df.crime.map(crime_map)
df_copy.head()
# Out:
#    state_code  mun_code  year  month                    crime  \
# 0           1         1  2011      1  "DELITOS PATRIMONIALES"
# 1           1         1  2011      2  "DELITOS PATRIMONIALES"
# 2           1         1  2011      3  "DELITOS PATRIMONIALES"
# 3           1         1  2011      4  "DELITOS PATRIMONIALES"
# 4           1         1  2011      5  "DELITOS PATRIMONIALES"
#
#                   category                  type               subtype  count  \
# 0  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   44.0
# 1  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   43.0
# 2  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   34.0
# 3  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   21.0
# 4  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   35.0
#
#    population  crime_cat
# 0    811483.0          1
# 1    812551.0          1
# 2    813619.0          1
# 3    814686.0          1
# 4    815754.0          1

# %%
list(df_copy.crime_cat.unique())
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# ### Normalizar valores
# Normalizar atributos es el proceso de estandarizar el rango de los valores de los atributos
# Es tambien conocida como feature scalling
# Hay varias manera de hacerlo:
#
# -Reescalando
#
# -Estandarizando
#
# -Unidad de escala

# %%
from sklearn import preprocessing

df_normalized = df.dropna().copy()
min_max_scaler = preprocessing.MinMaxScaler()
np_scaled = min_max_scaler.fit_transform(df_normalized['population'].values.reshape(-1,1))
df_normalized['population_norm'] = np_scaled.reshape(-1,1)
df_normalized.head()
# Out:
#    state_code  mun_code  year  month                    crime  \
# 0           1         1  2011      1  "DELITOS PATRIMONIALES"
# 1           1         1  2011      2  "DELITOS PATRIMONIALES"
# 2           1         1  2011      3  "DELITOS PATRIMONIALES"
# 3           1         1  2011      4  "DELITOS PATRIMONIALES"
# 4           1         1  2011      5  "DELITOS PATRIMONIALES"
#
#                   category                  type               subtype  count  \
# 0  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   44.0
# 1  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   43.0
# 2  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   34.0
# 3  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   21.0
# 4  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   35.0
2011        8712
#            2012        8712
#            2013        8712
#            2014        2904
# 5          2011       30096
#            2012       30096
#            2013       30096
#            2014       10032
# 6          2011          36
#            2012          36
#            2013          36
#            2014           8

# %%
df.groupby(['category', 'year'])[['crime', 'mun_code']].count()
# Out:
#                                          crime  mun_code
# category                           year
# "D                                 2014      1         1
# "DELITOS PATRIMONIALES"            2011   5916      5916
#                                    2012   5916      5916
#                                    2013   5916      5916
#                                    2014   1968      1968
# "DELITOS SEXUALES (VIOLACION)"     2011    840       840
#                                    2012    840       840
#                                    2013    840       840
#                                    2014    280       280
# "OTROS DELITOS"                    2011   3360      3360
#                                    2012   3360      3360
#                                    2013   3360      3360
#                                    2014   1120      1120
# "PRIV. DE LA LIBERTAD (SECUESTRO)" 2011    840       840
#                                    2012    840       840
#                                    2013    840       840
#                                    2014    280       280
# "ROBO COMUN"                       2011  11760     11760
#                                    2012  11760     11760
#                                    2013  11760     11760
#                                    2014   3920      3920
# "ROBO DE GANADO (ABIGEATO)"        2011    840       840
#                                    2012    840       840
#                                    2013    840       840
#                                    2014    280       280
# "ROBO EN CARRETERAS"               2011   8400      8400
#                                    2012   8400      8400
#                                    2013   8400      8400
#                                    2014   2800      2800
# "ROBO EN INSTITUCIONES BANCARIAS"  2011  10080     10080
#                                    2012  10080     10080
#                                    2013  10080     10080
#                                    2014   3360      3360
# HOMICIDIOS                         2011   6720      6720
#                                    2012   6720      6720
#                                    2013   6720      6720
#                                    2014   2240      2240
# LESIONES                           2011   6720      6720
#                                    2012   6720      6720
#                                    2013   6720      6720
#                                    2014   2240      2240

# %%
df_sample.groupby(['category', 'year'])[['crime', 'mun_code']].agg([np.sum, np.mean,
                                                              np.count_nonzero])
# Out:
#                                         mun_code
#                                              sum       mean count_nonzero
# category                           year
# "DELITOS PATRIMONIALES"            2011     3893  13.659649           285
#                                    2012     3785  12.328990           307
#                                    2013     3791  12.764310           297
#                                    2014     1123  11.459184            98
# "DELITOS SEXUALES (VIOLACION)"     2011      322   9.757576            33
#                                    2012      481  13.742857            35
#                                    2013      493  12.973684            38
#                                    2014      189  13.500000            14
# "OTROS DELITOS"                    2011     2732  13.868020           197
#                                    2012     2228  13.925000           160
#                                    2013     2274  13.865854           164
#                                    2014      696  13.920000            50
# "PRIV. DE LA LIBERTAD (SECUESTRO)" 2011      436  11.473684            38
#                                    2012      686  14.291667            48
#                                    2013      474  12.810811            37
#                                    2014      125   8.333333            15
# "ROBO COMUN"                       2011     6856  12.672828           541
#                                    2012     6961  13.158790           529
#                                    2013     7116  13.056881           545
#                                    2014     2763  12.971831           213
# "ROBO DE GANADO (ABIGEATO)"        2011      383  10.638889            36
#                                    2012      533  12.395349            43
#                                    2013      479  14.088235            34
#                                    2014      227  13.352941            17
# "ROBO EN CARRETERAS"               2011     5476  13.421569           408
#                                    2012     5509  13.436585           410
#                                    2013     6249  14.299771           437
#                                    2014     1547  11.375000           136
# "ROBO EN INSTITUCIONES BANCARIAS"  2011     6536  12.593449           519
#                                    2012     6961  13.412331           519
#                                    2013     7190  13.192661           545
#                                    2014     2228  12.516854           178
# HOMICIDIOS                         2011     4766  13.202216           361
#                                    2012     4994  13.107612           381
#                                    2013     3885  11.808511           329
#                                    2014     1354  12.537037           108
# LESIONES                           2011     4247  12.169054           349
#                                    2012     4707  13.334278           353
#                                    2013     3958  12.525316           316
#                                    2014     1833  14.902439           123

# %%
df_sample.groupby(['category', 'year']).agg({'month':np.mean,'population':np.max})
# Out:
#                                             month  population
# category                           year
# "DELITOS PATRIMONIALES"            2011  6.484211   1631186.0
#                                    2012  6.201954   1648609.0
#                                    2013  6.589226   1683398.0
#                                    2014  2.622449   1009808.0
# "DELITOS SEXUALES (VIOLACION)"     2011  6.787879    977608.0
#                                    2012  6.628571   1642079.0
#                                    2013  5.868421    769039.0
#                                    2014  2.071429   1006372.0
# "OTROS DELITOS"                    2011  6.761421   1618115.0
#                                    2012  6.218750   1652960.0
#                                    2013  6.567073   1681225.0
#                                    2014  2.180000    849274.0
# "PRIV. DE LA LIBERTAD (SECUESTRO)" 2011  5.657895    975294.0
#                                    2012  6.479167    826172.0
#                                    2013  7.000000   1661663.0
#                                    2014  2.400000    510395.0
# "ROBO COMUN"                       2011  6.432532   1631186.0
#                                    2012  6.415879   1652960.0
#                                    2013  6.609174   1683398.0
#                                    2014  2.483568   1692086.0
# "ROBO DE GANADO (ABIGEATO)"        2011  6.583333    819939.0
#                                    2012  6.255814   1655136.0
#                                    2013  6.941176    764590.0
#                                    2014  2.235294   1007518.0
# "ROBO EN CARRETERAS"               2011  6.323529   1631186.0
#                                    2012  6.441463   1655136.0
#                                    2013  6.965675   1681225.0
#                                    2014  2.588235   1692086.0
# "ROBO EN INSTITUCIONES BANCARIAS"  2011  6.564547   1629008.0
#                                    2012  6.529865   1655136.0
#                                    2013  6.555963   1674709.0
#                                    2014  2.578652   1692086.0
# HOMICIDIOS                         2011  6.709141   1620294.0
#                                    2012  6.330709   1657312.0
#                                    2013  6.410334   1681225.0
#                                    2014  2.370370   1692086.0
# LESIONES                           2011  6.412607   1629008.0
#                                    2012  6.580737   1657312.0
#                                    2013  6.708861   1681225.0
#                                    2014  2.528455   1687742.0

# %%
df_sample.groupby(['category', 'year']).agg({'population':{'total_population':np.sum,
                                                               'mean_population':np.mean,
                                                               'variance_population':np.std},
                                                               'month':np.mean})
# Out:
# /home/vagrant/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py:1455: FutureWarning: using a dict with renaming is deprecated and will be removed
# in a future version.
#
# For column-specific groupby renaming, use named aggregation
#
#     >>> df.groupby(...).agg(name=('column', aggfunc))
#
#   return super().aggregate(arg, *args, **kwargs)
#                                               population                  \
#                                         total_population mean_population
# category                           year
# "DELITOS PATRIMONIALES"            2011       38511500.0   135128.070175
#                                    2012       35585766.0   115914.547231
#                                    2013       41932836.0   141188.000000
#                                    2014        8421082.0    85929.408163
# "DELITOS SEXUALES (VIOLACION)"     2011        5420680.0   164263.030303
#                                    2012        4912641.0   140361.171429
#                                    2013        3948783.0   103915.342105
#                                    2014        3288384.0   234884.571429
# "OTROS DELITOS"                    2011       22564121.0   114538.685279
#                                    2012       28266833.0   176667.706250
#                                    2013       20134615.0   122772.042683
#                                    2014        8425395.0   168507.900000
# "PRIV. DE LA LIBERTAD (SECUESTRO)" 2011        4294410.0   113010.789474
#                                    2012        5206307.0   108464.729167
#                                    2013        4702545.0   127095.810811
#                                    2014        1391888.0    92792.533333
# "ROBO COMUN"                       2011       75823733.0   140154.774492
#                                    2012       79947971.0   151130.379962
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                   ylim=(-1.2, 1.2))

x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x))

# %%
# The lowest level of these is plt.subplot(), which creates a single subplot within a grid
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),
             fontsize=18, ha='center')

# %%
# plt.subplots_adjust can be used to adjust the spacing between these plots
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 7):
    ax = fig.add_subplot(2, 3, i)
    ax.text(0.5, 0.5, str((2, 3, i)),
           fontsize=18, ha='center')

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
for i in range(2):
    for j in range(3):
        ax[i, j].text(0.5, 0.5, str((i, j)),
                      fontsize=18, ha='center')
fig

# %%
# Create some normally distributed data
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='gray')
y_hist.invert_xaxis()

# %%
df_sample['year'] = df_sample['year'].astype('int64')

df_sample.plot(kind='scatter',x='year',y='population')

# %%
df_copy.plot(kind='scatter',x='population',y='crime_cat')

# %%
plt.hist(df_copy['crime_cat'])
plt.xlabel('Crime')
plt.ylabel('Frequency')
plt.title('Frequency of Crime')
# Out:
# Text(0.5, 1.0, 'Frequency of Crime')

# %%
keys = list(df.crime.unique())
vals = range(1,8)
crime_map = dict(zip(keys, vals))
crime_map
# Out:
# {'"DELITOS PATRIMONIALES"': 1,
#  '"DELITOS SEXUALES"': 2,
#  'HOMICIDIOS': 3,
#  'LESIONES': 4,
#  '"OTROS DELITOS"': 5,
#  '"PRIV. DE LA LIBERTAD (SECUESTRO)"': 6,
#  'ROBOS': 7}

# %%
df_copy['crime_cat'] = df.crime.map(crime_map)
df_copy.head()
# Out:
#    state_code  mun_code  year  month                    crime  \
# 0           1         1  2011      1  "DELITOS PATRIMONIALES"
# 1           1         1  2011      2  "DELITOS PATRIMONIALES"
# 2           1         1  2011      3  "DELITOS PATRIMONIALES"
# 3           1         1  2011      4  "DELITOS PATRIMONIALES"
# 4           1         1  2011      5  "DELITOS PATRIMONIALES"
#
#                   category                  type               subtype  count  \
# 0  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   44.0
# 1  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   43.0
# 2  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   34.0
# 3  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   21.0
# 4  "DELITOS PATRIMONIALES"  "ABUSO DE CONFIANZA"  "ABUSO DE CONFIANZA"   35.0
#
#    population  crime_cat
# 0    811483.0          1
# 1    812551.0          1
# 2    813619.0          1
# 3    814686.0          1
# 4    815754.0          1

# %% [markdown]
# ### BOXPLOT

# %%
plt.boxplot(df_sample['month'], showmeans=True, meanline=True)
plt.ylabel('Crime categories')
plt.title('Box Plot of Crime categories')
# Out:
# Text(0.5, 1.0, 'Box Plot of Crime categories')
